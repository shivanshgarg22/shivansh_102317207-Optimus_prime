# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshgarg22/shivansh_102317207-Optimus_prime/blob/main/Shivansh_102317207_assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
import numpy as np
import pandas as pd

rn=207
np.random.seed(rn)
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
categories = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

sales_data=np.random.randint(1000, 5001, size=(12, 4))

df = pd.DataFrame(sales_data, columns=categories, index=months)

print(df.head(5))
print(df.describe())


totals = df.sum()
print(totals)
totalm = df.sum(axis=1)
print(totalm)
growth_rates = df.pct_change().mean() * 100


df["Total Sales"] = totalm
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

print(df)

discounted_df = df.copy()
if rn % 2 == 0:
    discounted_df["Electronics"] *= 0.9
else:
   discounted_df["Clothing"] *= 0.85

discounted_df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4590      2586            2973    3464
# Feb         1078      3305            4067    4667
# Mar         1886      4152            4767    2989
# Apr         1853      4851            3297    1339
# May         1365      1217            4510    4144
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2662.166667  2957.500000     3678.750000  2981.500000
# std    1349.335111  1493.938571      829.827159  1061.247936
# min    1078.000000  1015.000000     2117.000000  1252.000000
# 25%    1645.750000  1451.750000     3156.750000  2441.250000
# 50%    1888.500000  2945.500000     3839.000000  3037.000000
# 75%    4035.000000  4248.750000     4246.750000  3681.250000
# max    4590.000000  4894.000000     4767.000000  4667.000000
# Electronics       31946
# Clothing          35490
# Home & Kitchen    44145
# Sports            35778
# dtype: int64
# Jan    13613
# Feb    13117
# Mar    13794
# Apr    11340
# May    11236
# Jun    15938
# Jul    10692
# Aug    12411
# Sep    12198
# Oct     9645
# Nov    10574
# Dec    12801
# dtype: int64
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4590      2586            2973    3464        13613          NaN
# Feb         1078      3305            4067    4667        13117    -3.643576
# Mar         1886      4152            4767    2989        13794     5.161241
# Apr         1853      4851            3297    1339        11340   -17.790344
# May         1365      1217            4510    4144        11236    -0.917108
# Jun         3925      4539            4672    2802        15938    41.847633
# Jul         4365      1209            3866    1252        10692   -32.915046
# Aug         4370      1015            3218    3808        12411    16.077441
# Sep         3424      1530            4159    3085        12198    -1.716219
# Oct         1692      3835            2117    2001         9645   -20.929661
# Nov         1891      2357            2687    3639        10574     9.631934
# Dec         1507      4894            3812    2588        12801    21.061093
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4590   2198.10            2973    3464        13613          NaN
# Feb         1078   2809.25            4067    4667        13117    -3.643576
# Mar         1886   3529.20            4767    2989        13794     5.161241
# Apr         1853   4123.35            3297    1339        11340   -17.790344
# May         1365   1034.45            4510    4144        11236    -0.917108
# Jun         3925   3858.15            4672    2802        15938    41.847633
# Jul         4365   1027.65            3866    1252        10692   -32.915046
# Aug         4370    862.75            3218    3808        12411    16.077441
# Sep         3424   1300.50            4159    3085        12198    -1.716219
# Oct         1692   3259.75            2117    2001         9645   -20.929661
# Nov         1891   2003.45            2687    3639        10574     9.631934
# Dec         1507   4159.90            3812    2588        12801    21.061093

# %%
#2
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
df.plot(kind='line', marker='o', title='Monthly Sales Trends')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend(loc='upper left')
plt.show()

# Box plots
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution by Category")
plt.show()

# %%
#3
array = np.array([[1, -2, 3], [-4, 5, -6]])
print(np.abs(array))
print(np.percentile(array, [25, 50, 75], axis=None))
print(np.percentile(array, [25, 50, 75], axis=0))
print(np.percentile(array, [25, 50, 75], axis=1))
print(np.mean(array))
print(np.median(array))
print(np.std(array))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [-3.5 -0.5  2.5]
# [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# -0.5
# -0.5
# 3.8622100754188224

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print(np.floor(a))
print(np.ceil(a))
print(np.trunc(a))
print(np.round(a))
# Out:
# [-2. -2. -1.  0.  1.  1.  3.]
# [-1. -1. -0.  1.  2.  2.  3.]
# [-1. -1. -0.  0.  1.  1.  3.]
# [-2. -2. -0.  0.  2.  2.  3.]

# %%
lst = [1, 2, 3, 4, 5]
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("Swapped List:", lst)
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %%
s = {10, 20, 30, 40, 50}
sl = list(s)
sl[0], sl[4] = sl[4], sl[0]
ss = set(sl)
print("Swapped Set:", ss)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
